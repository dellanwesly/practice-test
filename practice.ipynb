# %% [markdown]
# # Dellan Wesly, Data Science & Artificial Intelligence, c3709870
#
# **"I am submitting Exam Paper 3"**

# %% [markdown]
# ## How i work best when programming
#
# ### Environment and setup
#
# I work best in my room when its quiet and i have my music playing. I like to use **pycharm** with a *jupyter notebook* to keep my code organised and easy to read.
#
# ### prefered tools:
#
# - Python
# - Vscode
# - jupyter notebook
#
# ### style of work:
#
# - i like to add comments to my code to keep it organised and easy for someone new to understand my work
# - i like to break problems into smaller tasks

# %%
lap_time = float(input("Enter the lap time in seconds: "))

if lap_time < 50.5:
    print("Your lap time is below the standard")

else:
    print("Your lap time is above the standard")
# Out:
# Your lap time is below the standard
